# %% [markdown]
# # Feature Importance #

# %%
import pandas as pd
import numpy as np

from sklearn.metrics import SCORERS
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.metrics import mean_squared_error

from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import DistanceMetric

from sklearn.model_selection import train_test_split

from imblearn.under_sampling import RandomUnderSampler

from sklearn import preprocessing

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn import svm

import xgboost as xgb
from xgboost.sklearn import XGBClassifier

from sklearn.linear_model import SGDClassifier

from sklearn.preprocessing import MaxAbsScaler
from sklearn.kernel_approximation import RBFSampler

from sklearn.neural_network import MLPClassifier

from sklearn.ensemble import ExtraTreesClassifier

from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# Cargo los features de los csv

# %%
tf = pd.read_csv('../featuresMagui.csv') #mis features 
tf_1 = pd.read_csv('../features_seba.csv') #los features de Seba
tf_2 = pd.read_csv('../santi_timefeatures.csv')
tf_3 = pd.read_csv('../Santi_FeaturesConEventos.csv')
tf_4 = pd.read_csv('../featuresMagui2.csv')
tf_5 = pd.read_csv('../fetures_nuevos_santi.csv')
labels = pd.read_csv('../../data/labels_training_set.csv') #las personas de las cuales tengo Info
personas =pd.read_csv('../../data/trocafone_kaggle_test.csv') #las personas a las que le tengo que predecir

# %%
#Datos a entregar
datos = pd.merge(tf, tf_1, on = 'person', how = 'inner')
datos = pd.merge(datos, tf_2, on = 'person', how = 'inner')
datos = pd.merge(datos, tf_3, on = 'person', how = 'inner')
datos = pd.merge(datos, tf_4, on = 'person', how = 'inner')
datos = pd.merge(datos, tf_5, on = 'person', how = 'inner')
datos = pd.merge(personas, datos, on = 'person', how = 'inner')

# %%
#Datos para entrenar
labels_f = pd.merge(tf,tf_1, on = 'person',how = 'inner')
labels_f = pd.merge(labels_f,tf_2, on = 'person',how = 'inner')
labels_f = pd.merge(labels_f,tf_3, on = 'person',how = 'inner')
labels_f = pd.merge(labels_f,tf_4, on = 'person',how = 'inner')
labels_f = pd.merge(labels_f,tf_5, on = 'person',how = 'inner')
labels_f = pd.merge(labels, labels_f, on = 'person', how = 'inner')

# %%
labels_f = labels_f.drop('device_type', axis = 1)

# %%
datos = datos.drop('device_type', axis = 1)

# %%
labels_f.to_csv('../../data/labels_f.csv', encoding='utf-8', index=False)
datos.to_csv('../../data/datos.csv', encoding='utf-8', index=False)

# %%
labels_f.columns
# Out:
# Index(['person', 'label', 'Unnamed: 0_x', 'esNuevo', 'cantidadDeVisitas',
#        'ingresoPorPublicidad', 'Facebook', 'FacebookAds', 'FacebookSocial',
#        'MARKETING SOCIAL',
#        ...
#        'cadaCuantosMinutosHaceEventos', 'cadaCuantosDiasEnMes5HaceEventos',
#        'cadaCuantasHorasEnUnDiaDelMes5HaceEventos',
#        'cadaCuantosMinutosHaceEventosEnUnDiaYHoraDelMes5',
#        'cadaCuantosSegundosHaceEventosEnUnDiaYHoraDelMes5',
#        'cadaCuantasHorasHaceEventosEnSuUltimaConexionDelMes5',
#        'cadaCuantosMinutosHaceEventosEnSuUltimaConexionDelMes5',
#        'cadaCuantosSegundosHaceEventosEnSuUltimaConexionDelMes5',
#        'cadaCuantosDiasHaceConversion', 'cadaCuantosDiasHaceCheckout'],
#       dtype='object', length=1324)

# %%
X = labels_f.iloc[:,2:]
y = labels_f.iloc[:,1:2]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.1, random_state= 123)

# %%
clf = RandomForestClassifier(n_estimators=100, max_depth=2, random_state=0)
clf_1 = ExtraTreesClassifier()
clf_2 = AdaBoostClassifier()
clf_3  = GradientBoostingClassifier()
clf_4 = XGBClassifier(learning_rate =0.05,n_estimators=1000,max_depth=5,min_child_weight=1,gamma=0,
                           subsample=0.8,colsample_bytree=0.8,objective= 'binary:logistic',nthread=4,
                            seed=27)
clasificadores = [(clf,False), (clf_1,False), (clf_2,False), (clf_3,False), (clf_4,True)]

# %%
for clasificador in clasificadores: 
    if(clasificador[1]):
        clasificador[0].fit(X_train, y_train, early_stopping_rounds = 5, eval_set=[(X_test, y_test)])
    else:
        clasificador[0].fit(X_train, y_train)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [0]	validation_0-error:0.052523
# Will train until validation_0-error hasn't improved in 5 rounds.
# [1]	validation_0-error:0.047889
# [2]	validation_0-error:0.051493
# [3]	validation_0-error:0.050463
# [4]	validation_0-error:0.049949
# [5]	validation_0-error:0.050978
# [6]	validation_0-error:0.048919
# Stopping. Best iteration:
# [1]	validation_0-error:0.047889

# %%
importanciaPorFeature = []
features = X.columns.tolist()
i = 1
for clasificador in clasificadores:        
    importanciaPorFeature.append((clasificador[0].feature_importances_)*i)
    i-0.25

# %%
importancia = {}
x = 0
for i in range(5):
    for feature in importanciaPorFeature[i]:
        importancia[features[x]] = importancia.get(features[x], 0)
        importancia[features[x]]+= feature
        x+=1
    x=0

# %%
for importancia_feat in importancia.keys():
    importancia[importancia_feat] /= 5

# %%
[importancia_feat,importancia[importancia_feat]
# Out:
#   File "<ipython-input-89-d2eee00b72b3>", line 1
#     [importancia_feat,importancia[importancia_feat]
#                                                    ^
# SyntaxError: unexpected EOF while parsing

# %%
atributos_importantes = []
for importancia_feat in importancia.keys():
    if importancia[importancia_feat] > 0.003:
        atributos_importantes.append(importancia_feat)

# %%
atributos_k_importantes = []
for importancia_feat in importancia.keys():
    atributos_k_importantes.append([[importancia_feat,importancia[importancia_feat]])
# Out:
#   File "<ipython-input-91-706b7b0fa4f2>", line 3
#     atributos_k_importantes.append([[importancia_feat,importancia[importancia_feat]])
#                                                                                     ^
# SyntaxError: invalid syntax

# %%
len(atributos_importantes)
# Out:
# 82

# %%
#atributos_importantes

# %%
atributos_importantes.append('label')
atributos_importantes.append('person')
#atributos_label = atributos_importantes.append('person')
labels_f_filtrado= labels_f.loc[:,atributos_importantes]

# %%
labels_f_filtrado.head()
# Out:
#    Unnamed: 0_x  deviceSmartphone  cantVisitasAVP  cantDirect  cantPaid  \
# 0         13592              True            23.0         8.0       0.0
# 1         16312              True             1.0         0.0       1.0
# 2         26194              True            31.0         2.0       6.0
# 3         21297              True            24.0         0.0       0.0
# 4         28866             False             9.0         0.0       1.0
#
#    cantidadDeEventos  cantCheckout  cantViewedProduct  cantVisitedSite  \
# 0               67.0           1.0               23.0             17.0
# 1                2.0           0.0                0.0              1.0
# 2               96.0           1.0               31.0             22.0
# 3               37.0           0.0               24.0              4.0
# 4               17.0           2.0                9.0              1.0
#
#    checkout_x    ...     cadaCuantosDiasEnMes5HaceEventos  \
# 0        True    ...                                  1.0
# 1       False    ...                                  0.0
# 2        True    ...                                 27.0
# 3       False    ...                                  3.0
# 4        True    ...                                  1.0
#
#    cadaCuantosMinutosHaceEventosEnUnDiaYHoraDelMes5  \
# 0                                               0.0
# 1                                               0.0
# 2                                               3.0
# 3                                               2.0
# 4                                               2.0
#
#    cadaCuantosSegundosHaceEventosEnUnDiaYHoraDelMes5  \
# 0                                               17.0
# 1                                                0.0
# 2                                              148.0
# 3                                               57.0
# 4                                               78.0
#
#    cadaCuantasHorasHaceEventosEnSuUltimaConexionDelMes5  \
# 0                                                0.0
# 1                                                0.0
# 2                                                4.0
# 3                                                0.0
# 4                                                0.0
#
#    cadaCuantosMinutosHaceEventosEnSuUltimaConexionDelMes5  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                           3.333333
# 3                                           0.000000
# 4                                           0.000000
#
#    cadaCuantosSegundosHaceEventosEnSuUltimaConexionDelMes5  \
# 0                                                1.0
# 1                                                0.0
# 2                                              153.0
# 3                                                3.0
# 4                                                0.0
#
#    cadaCuantosDiasHaceConversion  cadaCuantosDiasHaceCheckout  label    person
# 0                            0.0                          0.0      0  0566e9c1
# 1                           -1.0                         -1.0      0  6ec7ee77
# 2                           -1.0                          0.0      0  abe7a2fb
# 3                           -1.0                         -1.0      0  34728364
# 4                           -1.0                          0.0      0  87ed62de
#
# [5 rows x 84 columns]

# %%
labels_f_filtrado.to_csv('../../data/labels_f_filtrado.csv', encoding='utf-8', index=False)

# %%
atributos_importantes.remove('label')

# %%
datos_filtrado = datos.loc[:,atributos_importantes]
datos_filtrado.head()
# Out:
#    Unnamed: 0_x  deviceSmartphone  cantVisitasAVP  cantDirect  cantPaid  \
# 0             0              True             4.0         0.0       0.0
# 1             2              True           404.0        56.0      21.0
# 2             3             False            13.0         0.0       1.0
# 3             4             False           739.0         1.0       6.0
# 4             5              True           177.0         2.0       6.0
#
#    cantidadDeEventos  cantCheckout  cantViewedProduct  cantVisitedSite  \
# 0                9.0           1.0                4.0              1.0
# 1              567.0           7.0              404.0             95.0
# 2               26.0           1.0               13.0              2.0
# 3              836.0           1.0              739.0             22.0
# 4              257.0           2.0              177.0             20.0
#
#    checkout_x    ...     cadaCuantasHorasHaceEventos  \
# 0        True    ...                               0
# 1        True    ...                              34
# 2        True    ...                             235
# 3        True    ...                              21
# 4        True    ...                               5
#
#    cadaCuantosDiasEnMes5HaceEventos  \
# 0                               0.0
# 1                               2.0
# 2                               9.0
# 3                               2.0
# 4                               1.0
#
#    cadaCuantosMinutosHaceEventosEnUnDiaYHoraDelMes5  \
# 0                                               8.0
# 1                                               3.0
# 2                                               2.0
# 3                                               3.0
# 4                                               2.0
#
#    cadaCuantosSegundosHaceEventosEnUnDiaYHoraDelMes5  \
# 0                                              198.0
# 1                                               62.0
# 2                                               27.0
# 3                                               41.0
# 4                                               34.0
#
#    cadaCuantasHorasHaceEventosEnSuUltimaConexionDelMes5  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
# 3                                                5.0
# 4                                                0.0
#
#    cadaCuantosMinutosHaceEventosEnSuUltimaConexionDelMes5  \
# 0                                               8.00
# 1                                               1.00
# 2                                               1.00
# 3                                               9.75
# 4                                               0.00
#
#    cadaCuantosSegundosHaceEventosEnSuUltimaConexionDelMes5  \
# 0                                              198.0
# 1                                               12.0
# 2                                               29.0
# 3                                              178.5
# 4                                                4.0
#
#    cadaCuantosDiasHaceConversion  cadaCuantosDiasHaceCheckout    person
# 0                           -1.0                          0.0  4886f805
# 1                           -1.0                         24.0  0297fc1e
# 2                           -1.0                          0.0  2d681dd8
# 3                           -1.0                          0.0  cccea85e
# 4                           -1.0                          0.0  4c8a8b93
#
# [5 rows x 83 columns]

# %%
datos_filtrado.to_csv('../../data/datos_filtrado.csv', encoding='utf-8', index=False)
