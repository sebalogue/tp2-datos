# %%
import pandas as pd
import numpy as np

import pandas as pd
import numpy as np

from sklearn.metrics import SCORERS
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.metrics import mean_squared_error

from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import DistanceMetric

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV 
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate


from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler

from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.under_sampling import TomekLinks
from imblearn.under_sampling import ClusterCentroids
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTETomek

from sklearn import preprocessing

from sklearn.ensemble import RandomForestClassifier

import xgboost as xgb
from xgboost.sklearn import XGBClassifier

# %%
tf = pd.read_csv('featuresMagui.csv') #mis features 
tf_seba = pd.read_csv('features_seba.csv') #los features de Seba
tf_santi = pd.read_csv('santi_timefeatures.csv')
tf_santi_2 = pd.read_csv('Santi_FeaturesConEventos.csv')
tf_2 = pd.read_csv('featuresMagui2.csv')
labels = pd.read_csv('../data/labels_training_set.csv') #las personas de las cuales tengo Info
personas =pd.read_csv('../data/trocafone_kaggle_test.csv') #las personas a las que le tengo que predecir

# %%
#Datos a entregar
datos = pd.merge(tf, tf_seba, on = 'person', how = 'inner')
datos = pd.merge(datos, tf_santi, on = 'person', how = 'inner')
datos = pd.merge(datos, tf_santi_2, on = 'person', how = 'inner')
datos = pd.merge(datos, tf_2, on = 'person', how = 'inner')
datos = pd.merge(personas, datos, on = 'person', how = 'inner')

# %%
#Datos para entrenar
labels_f = pd.merge(tf,tf_seba, on = 'person',how = 'inner')
labels_f = pd.merge(labels_f,tf_santi, on = 'person',how = 'inner')
labels_f = pd.merge(labels_f,tf_santi_2, on = 'person',how = 'inner')
labels_f = pd.merge(tf,tf_2, on = 'person',how = 'inner')
labels_f = pd.merge(labels, labels_f, on = 'person', how = 'inner')

# %%
labels_f.columns
# Out:
# Index(['person', 'label', 'Unnamed: 0', 'esNuevo', 'cantidadDeVisitas',
#        'ingresoPorPublicidad', 'Facebook', 'FacebookAds', 'FacebookSocial',
#        'MARKETING SOCIAL',
#        ...
#        'city_Woodbridge', 'city_Wrexham', 'city_Xambioa', 'city_Xanxere',
#        'city_Xavantina', 'city_Xaxim', 'city_Xexeu', 'city_Xinguara',
#        'city_Yellowknife', 'city_Ze Doca'],
#       dtype='object', length=3220)

# %%
y = labels_f.iloc[:,1:2]
X = labels_f.iloc[:,3: 3220]

# %%
X = X.drop('device_type', axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.1, random_state= 123)

# %%
rus= RandomUnderSampler(return_indices=True)

#id_rus son los índices
#X_train, y_train, id_rus = rus.fit_sample(X_train, y_train)

# %%
clf = RandomForestClassifier(n_estimators=100, max_depth=2, random_state=0)

# %%
clf.fit(X_train, y_train)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=2, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
preds = clf.predict(X_test)
preds_prob = clf.predict_proba(X_test)[:,1]
train_accuracy = accuracy_score(y_train, clf.predict(X_train))
test_accuracy = accuracy_score(y_test, preds)
area_debajo_de_curva = roc_auc_score(y_test, preds_prob)
matriz_de_confusion = confusion_matrix(y_test, preds)
print('train acurracy: ')
print(train_accuracy)
print('test acurracy: ')
print(test_accuracy)
print('Matriz de confusión: ')
print(matriz_de_confusion)
print('Área bajo la curva: ')
print(area_debajo_de_curva)
# Out:
# train acurracy:
# 0.949290293040293
# test acurracy:
# 0.9515962924819773
# Matriz de confusión:
# [[1848    0]
#  [  94    0]]
# Área bajo la curva:
# 0.7434230220134475

# %%
importancia = clf.feature_importances_
cantidad_de_features = len(importancia)
#for columna in datos

# %%
importancia_con_nombre = {}
features = X.columns
for i in range(cantidad_de_features):
    importancia_con_nombre[features[i]] = importancia[i]
importancia_con_nombre
# Out:
# {'esNuevo': 0.006095118287233974,
#  'cantidadDeVisitas': 0.01746703981922576,
#  'ingresoPorPublicidad': 0.0,
#  'Facebook': 0.0,
#  'FacebookAds': 0.0,
#  'FacebookSocial': 0.0,
#  'MARKETING SOCIAL': 0.0,
#  'afiliado': 0.0,
#  'afilio': 0.0,
#  'bing': 0.0,
#  'blog': 0.0,
#  'buscape': 0.0029678984287216954,
#  'criteo': 0.0010780067825024357,
#  'datacrush': 0.0,
#  'emblue': 0.0,
#  'gizmodo': 0.0,
#  'google': 0.002852650843489528,
#  'indexa': 0.0,
#  'manifest': 0.0,
#  'mercadopago': 0.0,
#  'onsite': 0.0,
#  'rakuten': 0.0,
#  'rtbhouse': 0.0009804230250060446,
#  'voxus': 0.0,
#  'yotpo': 0.0,
#  'zanox': 0.0,
#  'deviceSmartphone': 0.0,
#  'deviceComputer': 0.0,
#  'deviceTablet': 0.0,
#  'deviceUnknown': 0.0,
#  'cantVisitasAVP': 0.026378068500544014,
#  'maniana': 0.0,
#  'tarde': 0.015441272302419554,
#  'noche': 0.013520440294327783,
#  'madrugada': 0.0,
#  'cantDirect': 0.013447677380466608,
#  'cantEmail': 0.0,
#  'cantOrganic': 0.00435962612912365,
#  'cantPaid': 0.0,
#  'cantReferral': 0.0184046566675452,
#  'cantSocial': 0.0,
#  'cantUnknown': 0.0,
#  'cantVisitasDomingo': 0.009786701742002475,
#  'cantVisitasLunes': 0.009538733959263223,
#  'cantVisitasMartes': 0.00857480138049362,
#  'cantVisitasMiercoles': 0.011227422906780797,
#  'cantVisitasJueves': 0.011004334446706369,
#  'cantVisitasViernes': 0.0,
#  'cantVisitasSabado': 0.0,
#  'cantidadDeEventos': 0.03554923484514887,
#  'cantAdCampaignHit': 0.0016297149196193184,
#  'cantBandListing': 0.0033288934396954696,
#  'cantCheckout': 0.018412145381197544,
#  'cantGenericListing': 0.026807340790544146,
#  'cantLead': 0.0,
#  'cantSearchEngineHit': 0.011437923717126581,
#  'cantSearchedProducts': 0.002293128340324023,
#  'cantStaticpage': 0.0,
#  'cantViewedProduct': 0.029558628608178834,
#  'cantVisitedSite': 0.017100331545141224,
#  'visitaALaManiana': 0.0,
#  'visitaALaNoche': 0.0,
#  'visitaALaTarde': 0.00375823712406932,
#  'visitaALaMadrugada': 0.0,
#  'canalDirect': 0.00728400339241493,
#  'canalEmail': 0.0,
#  'canalOrganic': 0.0,
#  'canalPaid': 0.0,
#  'canalRefferal': 0.0042252559355676,
#  'canalSocial': 0.0,
#  'adCampaignHit': 0.0,
#  'bandListing': 0.005295043907954075,
#  'checkout': 0.008589602648180908,
#  'genericListing': 0.005063348050976872,
#  'searchEngineHit': 0.014936409606462331,
#  'searchedProducts': 0.0,
#  'staticpage': 0.0,
#  'viewedProduct': 0.0,
#  'visitedSite': 0.0,
#  'lead': 0.0,
#  'ingresoXFacebook': 0.0,
#  'ingresoXFacebookAds': 0.0,
#  'ingresoXFacebookSocial': 0.0,
#  'ingresoXMARKETING SOCIAL': 0.0,
#  'ingresoXafiliado': 0.0,
#  'ingresoXafilio': 0.0,
#  'ingresoXbing': 0.0,
#  'ingresoXblog': 0.0,
#  'ingresoXbuscape': 0.0,
#  'ingresoXcriteo': 0.0,
#  'ingresoXdatacrush': 0.0,
#  'ingresoXemblue': 0.0,
#  'ingresoXgizmodo': 0.0,
#  'ingresoXgoogle': 0.0,
#  'ingresoXindexa': 0.0,
#  'ingresoXmanifest': 0.0,
#  'ingresoXmercadopago': 0.0,
#  'ingresoXonsite': 0.0,
#  'ingresoXrakuten': 0.0,
#  'ingresoXrtbhouse': 0.0,
#  'ingresoXvoxus': 0.0,
#  'ingresoXyotpo': 0.0,
#  'ingresoXzanox': 0.0,
#  'index': 0.0017621769828609869,
#  'dayOfTheYear_1deCheckout': 0.0,
#  'dayOfTheYear_2deCheckout': 0.0,
#  'dayOfTheYear_3deCheckout': 0.0,
#  'dayOfTheYear_4deCheckout': 0.0,
#  'dayOfTheYear_5deCheckout': 0.0,
#  'dayOfTheYear_6deCheckout': 0.0,
#  'dayOfTheYear_7deCheckout': 0.0,
#  'dayOfTheYear_8deCheckout': 0.0,
#  'dayOfTheYear_9deCheckout': 0.0,
#  'dayOfTheYear_10deCheckout': 0.0,
#  'dayOfTheYear_11deCheckout': 0.0,
#  'dayOfTheYear_12deCheckout': 0.0,
#  'dayOfTheYear_13deCheckout': 0.0,
#  'dayOfTheYear_14deCheckout': 0.0,
#  'dayOfTheYear_15deCheckout': 0.0,
#  'dayOfTheYear_16deCheckout': 0.0,
#  'dayOfTheYear_17deCheckout': 0.0,
#  'dayOfTheYear_18deCheckout': 0.0,
#  'dayOfTheYear_19deCheckout': 0.0,
#  'dayOfTheYear_20deCheckout': 0.0,
#  'dayOfTheYear_21deCheckout': 0.0,
#  'dayOfTheYear_22deCheckout': 0.0,
#  'dayOfTheYear_23deCheckout': 0.0,
#  'dayOfTheYear_24deCheckout': 0.0,
#  'dayOfTheYear_25deCheckout': 0.0,
#  'dayOfTheYear_26deCheckout': 0.0,
#  'dayOfTheYear_27deCheckout': 0.0,
#  'dayOfTheYear_28deCheckout': 0.0,
#  'dayOfTheYear_29deCheckout': 0.0,
#  'dayOfTheYear_30deCheckout': 0.0,
#  'dayOfTheYear_31deCheckout': 0.0,
#  'dayOfTheYear_32deCheckout': 0.0,
#  'dayOfTheYear_33deCheckout': 0.0,
#  'dayOfTheYear_34deCheckout': 0.0,
#  'dayOfTheYear_35deCheckout': 0.0,
#  'dayOfTheYear_36deCheckout': 0.0,
#  'dayOfTheYear_37deCheckout': 0.005900502019687682,
#  'dayOfTheYear_38deCheckout': 0.0,
#  'dayOfTheYear_39deCheckout': 0.0027202826706416196,
#  'dayOfTheYear_40deCheckout': 0.0,
#  'dayOfTheYear_41deCheckout': 0.0,
#  'dayOfTheYear_42deCheckout': 0.0,
#  'dayOfTheYear_43deCheckout': 0.0,
#  'dayOfTheYear_44deCheckout': 0.0,
#  'dayOfTheYear_45deCheckout': 0.0,
#  'dayOfTheYear_46deCheckout': 0.0,
#  'dayOfTheYear_47deCheckout': 0.0,
#  'dayOfTheYear_48deCheckout': 0.0,
#  'dayOfTheYear_49deCheckout': 0.0,
#  'dayOfTheYear_50deCheckout': 0.0,
#  'dayOfTheYear_51deCheckout': 0.0,
#  'dayOfTheYear_52deCheckout': 0.0,
#  'dayOfTheYear_53deCheckout': 0.0,
#  'dayOfTheYear_54deCheckout': 0.0,
#  'dayOfTheYear_55deCheckout': 0.0,
#  'dayOfTheYear_56deCheckout': 0.004238443126890307,
#  'dayOfTheYear_57deCheckout': 0.0,
#  'dayOfTheYear_58deCheckout': 0.0,
#  'dayOfTheYear_59deCheckout': 0.0,
#  'dayOfTheYear_60deCheckout': 0.0,
#  'dayOfTheYear_61deCheckout': 0.0,
#  'dayOfTheYear_62deCheckout': 0.0,
#  'dayOfTheYear_63deCheckout': 0.0,
#  'dayOfTheYear_64deCheckout': 0.0,
#  'dayOfTheYear_65deCheckout': 0.0,
#  'dayOfTheYear_66deCheckout': 0.0,
#  'dayOfTheYear_67deCheckout': 0.0,
#  'dayOfTheYear_68deCheckout': 0.0,
#  'dayOfTheYear_69deCheckout': 0.0,
#  'dayOfTheYear_70deCheckout': 0.0,
#  'dayOfTheYear_71deCheckout': 0.0,
#  'dayOfTheYear_72deCheckout': 0.004479257259539278,
#  'dayOfTheYear_73deCheckout': 0.0,
#  'dayOfTheYear_74deCheckout': 0.0,
#  'dayOfTheYear_75deCheckout': 0.0,
#  'dayOfTheYear_76deCheckout': 0.0,
#  'dayOfTheYear_77deCheckout': 0.0,
#  'dayOfTheYear_78deCheckout': 0.0,
#  'dayOfTheYear_79deCheckout': 0.0,
#  'dayOfTheYear_80deCheckout': 0.003818181533768375,
#  'dayOfTheYear_81deCheckout': 0.0,
#  'dayOfTheYear_82deCheckout': 0.014569444384079852,
#  'dayOfTheYear_83deCheckout': 0.0,
#  'dayOfTheYear_84deCheckout': 0.0,
#  'dayOfTheYear_85deCheckout': 0.0,
#  'dayOfTheYear_86deCheckout': 0.0,
#  'dayOfTheYear_87deCheckout': 0.0,
#  'dayOfTheYear_88deCheckout': 0.0,
#  'dayOfTheYear_89deCheckout': 0.0,
#  'dayOfTheYear_90deCheckout': 0.0,
#  'dayOfTheYear_91deCheckout': 0.0,
#  'dayOfTheYear_92deCheckout': 0.0,
#  'dayOfTheYear_93deCheckout': 0.0022399806299921413,
#  'dayOfTheYear_94deCheckout': 0.0,
#  'dayOfTheYear_95deCheckout': 0.0,
#  'dayOfTheYear_96deCheckout': 0.0,
#  'dayOfTheYear_97deCheckout': 0.0,
#  'dayOfTheYear_98deCheckout': 0.0,
#  'dayOfTheYear_99deCheckout': 0.0,
#  'dayOfTheYear_100deCheckout': 0.0,
#  'dayOfTheYear_101deCheckout': 0.0,
#  'dayOfTheYear_102deCheckout': 0.0,
#  'dayOfTheYear_103deCheckout': 0.0,
#  'dayOfTheYear_104deCheckout': 0.0,
#  'dayOfTheYear_105deCheckout': 0.0,
#  'dayOfTheYear_106deCheckout': 0.0,
#  'dayOfTheYear_107deCheckout': 0.0,
#  'dayOfTheYear_108deCheckout': 0.0,
#  'dayOfTheYear_109deCheckout': 0.008592794610737748,
#  'dayOfTheYear_110deCheckout': 0.0,
#  'dayOfTheYear_111deCheckout': 0.0,
#  'dayOfTheYear_112deCheckout': 0.0,
#  'dayOfTheYear_113deCheckout': 0.0,
#  'dayOfTheYear_114deCheckout': 0.0,
#  'dayOfTheYear_115deCheckout': 0.006157876716388082,
#  'dayOfTheYear_116deCheckout': 0.0,
#  'dayOfTheYear_117deCheckout': 0.0,
#  'dayOfTheYear_118deCheckout': 0.0,
#  'dayOfTheYear_119deCheckout': 0.0,
#  'dayOfTheYear_120deCheckout': 0.0,
#  'dayOfTheYear_121deCheckout': 0.0,
#  'dayOfTheYear_122deCheckout': 0.0,
#  'dayOfTheYear_123deCheckout': 0.0032403914926564777,
#  'dayOfTheYear_124deCheckout': 0.0,
#  'dayOfTheYear_125deCheckout': 0.0,
#  'dayOfTheYear_126deCheckout': 0.0,
#  'dayOfTheYear_127deCheckout': 0.0,
#  'dayOfTheYear_128deCheckout': 0.0,
#  'dayOfTheYear_129deCheckout': 0.0,
#  'dayOfTheYear_130deCheckout': 0.0,
#  'dayOfTheYear_131deCheckout': 0.0,
#  'dayOfTheYear_132deCheckout': 0.0014959407642854735,
#  'dayOfTheYear_133deCheckout': 0.0,
#  'dayOfTheYear_134deCheckout': 0.0,
#  'dayOfTheYear_135deCheckout': 0.0007969266082531719,
#  'dayOfTheYear_136deCheckout': 0.0,
#  'dayOfTheYear_137deCheckout': 0.0,
#  'dayOfTheYear_138deCheckout': 0.0,
#  'dayOfTheYear_139deCheckout': 0.0,
#  'dayOfTheYear_140deCheckout': 0.0,
#  'dayOfTheYear_141deCheckout': 0.003014048920668237,
#  'dayOfTheYear_142deCheckout': 0.0,
#  'dayOfTheYear_143deCheckout': 0.0,
#  'dayOfTheYear_144deCheckout': 0.0,
#  'dayOfTheYear_145deCheckout': 0.0,
#  'dayOfTheYear_146deCheckout': 0.0,
#  'dayOfTheYear_147deCheckout': 0.0,
#  'dayOfTheYear_148deCheckout': 0.0,
#  'dayOfTheYear_149deCheckout': 0.0012535754191672374,
#  'dayOfTheYear_150deCheckout': 0.0,
#  'dayOfTheYear_151deCheckout': 0.0021345993385419714,
#  'dayOfTheYear_1deVisitedSite': 0.0,
#  'dayOfTheYear_2deVisitedSite': 0.0,
#  'dayOfTheYear_3deVisitedSite': 0.0,
#  'dayOfTheYear_4deVisitedSite': 0.0,
#  'dayOfTheYear_5deVisitedSite': 0.0,
#  'dayOfTheYear_6deVisitedSite': 0.0,
#  'dayOfTheYear_7deVisitedSite': 0.0,
#  'dayOfTheYear_8deVisitedSite': 0.0,
#  'dayOfTheYear_9deVisitedSite': 0.0,
#  'dayOfTheYear_10deVisitedSite': 0.0016325715824430712,
#  'dayOfTheYear_11deVisitedSite': 0.0,
#  'dayOfTheYear_12deVisitedSite': 0.0,
#  'dayOfTheYear_13deVisitedSite': 0.0,
#  'dayOfTheYear_14deVisitedSite': 0.0,
#  'dayOfTheYear_15deVisitedSite': 0.0,
#  'dayOfTheYear_16deVisitedSite': 0.0,
#  'dayOfTheYear_17deVisitedSite': 0.0,
#  'dayOfTheYear_18deVisitedSite': 0.0,
#  'dayOfTheYear_19deVisitedSite': 0.0,
#  'dayOfTheYear_20deVisitedSite': 0.0,
#  'dayOfTheYear_21deVisitedSite': 0.0,
#  'dayOfTheYear_22deVisitedSite': 0.0,
#  'dayOfTheYear_23deVisitedSite': 0.0016164939300814826,
#  'dayOfTheYear_24deVisitedSite': 0.0,
#  'dayOfTheYear_25deVisitedSite': 0.0,
#  'dayOfTheYear_26deVisitedSite': 0.0,
#  'dayOfTheYear_27deVisitedSite': 0.0,
#  'dayOfTheYear_28deVisitedSite': 0.0,
#  'dayOfTheYear_29deVisitedSite': 0.0,
#  'dayOfTheYear_30deVisitedSite': 0.0,
#  'dayOfTheYear_31deVisitedSite': 0.0,
#  'dayOfTheYear_32deVisitedSite': 0.0,
#  'dayOfTheYear_33deVisitedSite': 0.0,
#  'dayOfTheYear_34deVisitedSite': 0.0,
#  'dayOfTheYear_35deVisitedSite': 0.0,
#  'dayOfTheYear_36deVisitedSite': 0.0,
#  'dayOfTheYear_37deVisitedSite': 0.0,
#  'dayOfTheYear_38deVisitedSite': 0.0,
#  'dayOfTheYear_39deVisitedSite': 0.0,
#  'dayOfTheYear_40deVisitedSite': 0.0,
#  'dayOfTheYear_41deVisitedSite': 0.0,
#  'dayOfTheYear_42deVisitedSite': 0.0,
#  'dayOfTheYear_43deVisitedSite': 0.0,
#  'dayOfTheYear_44deVisitedSite': 0.0,
#  'dayOfTheYear_45deVisitedSite': 0.0,
#  'dayOfTheYear_46deVisitedSite': 0.0,
#  'dayOfTheYear_47deVisitedSite': 0.0,
#  'dayOfTheYear_48deVisitedSite': 0.0,
#  'dayOfTheYear_49deVisitedSite': 0.0,
#  'dayOfTheYear_50deVisitedSite': 0.0,
#  'dayOfTheYear_51deVisitedSite': 0.0,
#  'dayOfTheYear_52deVisitedSite': 0.0,
#  'dayOfTheYear_53deVisitedSite': 0.0,
#  'dayOfTheYear_54deVisitedSite': 0.0,
#  'dayOfTheYear_55deVisitedSite': 0.0,
#  'dayOfTheYear_56deVisitedSite': 0.0,
#  'dayOfTheYear_57deVisitedSite': 0.0,
#  'dayOfTheYear_58deVisitedSite': 0.0,
#  'dayOfTheYear_59deVisitedSite': 0.0,
#  'dayOfTheYear_60deVisitedSite': 0.0,
#  'dayOfTheYear_61deVisitedSite': 0.0,
#  'dayOfTheYear_62deVisitedSite': 0.0,
#  'dayOfTheYear_63deVisitedSite': 0.0,
#  'dayOfTheYear_64deVisitedSite': 0.0,
#  'dayOfTheYear_65deVisitedSite': 0.0,
#  'dayOfTheYear_66deVisitedSite': 0.0,
#  'dayOfTheYear_67deVisitedSite': 0.0,
#  'dayOfTheYear_68deVisitedSite': 0.0038492491108435933,
#  'dayOfTheYear_69deVisitedSite': 0.0,
#  'dayOfTheYear_70deVisitedSite': 0.0,
#  'dayOfTheYear_71deVisitedSite': 0.0,
#  'dayOfTheYear_72deVisitedSite': 0.0,
#  'dayOfTheYear_73deVisitedSite': 0.0,
#  'dayOfTheYear_74deVisitedSite': 0.0,
#  'dayOfTheYear_75deVisitedSite': 0.0,
#  'dayOfTheYear_76deVisitedSite': 0.0,
#  'dayOfTheYear_77deVisitedSite': 0.0,
#  'dayOfTheYear_78deVisitedSite': 0.0,
#  'dayOfTheYear_79deVisitedSite': 0.0,
#  'dayOfTheYear_80deVisitedSite': 0.0014279024610506287,
#  'dayOfTheYear_81deVisitedSite': 0.0015818212588234774,
#  'dayOfTheYear_82deVisitedSite': 0.0,
#  'dayOfTheYear_83deVisitedSite': 0.0,
#  'dayOfTheYear_84deVisitedSite': 0.0,
#  'dayOfTheYear_85deVisitedSite': 0.0,
#  'dayOfTheYear_86deVisitedSite': 0.0,
#  'dayOfTheYear_87deVisitedSite': 0.0,
#  'dayOfTheYear_88deVisitedSite': 0.0,
#  'dayOfTheYear_89deVisitedSite': 0.010892683630546325,
#  'dayOfTheYear_90deVisitedSite': 0.0,
#  'dayOfTheYear_91deVisitedSite': 0.0,
#  'dayOfTheYear_92deVisitedSite': 0.005741604304399236,
#  'dayOfTheYear_93deVisitedSite': 0.0,
#  'dayOfTheYear_94deVisitedSite': 0.0,
#  'dayOfTheYear_95deVisitedSite': 0.0,
#  'dayOfTheYear_96deVisitedSite': 0.0,
#  'dayOfTheYear_97deVisitedSite': 0.0029768572711912334,
#  'dayOfTheYear_98deVisitedSite': 0.0022329147366982457,
#  'dayOfTheYear_99deVisitedSite': 0.0,
#  'dayOfTheYear_100deVisitedSite': 0.0,
#  'dayOfTheYear_101deVisitedSite': 0.0,
#  'dayOfTheYear_102deVisitedSite': 0.0,
#  'dayOfTheYear_103deVisitedSite': 0.0030784332764975646,
#  'dayOfTheYear_104deVisitedSite': 0.0,
#  'dayOfTheYear_105deVisitedSite': 0.0,
#  'dayOfTheYear_106deVisitedSite': 0.0,
#  'dayOfTheYear_107deVisitedSite': 0.0,
#  'dayOfTheYear_108deVisitedSite': 0.0,
#  'dayOfTheYear_109deVisitedSite': 0.00126034301571835,
#  'dayOfTheYear_110deVisitedSite': 0.013512788768555639,
#  'dayOfTheYear_111deVisitedSite': 0.0,
#  'dayOfTheYear_112deVisitedSite': 0.0,
#  'dayOfTheYear_113deVisitedSite': 0.006071614518328967,
#  'dayOfTheYear_114deVisitedSite': 0.003196493229739829,
#  'dayOfTheYear_115deVisitedSite': 0.0021663116985318077,
#  'dayOfTheYear_116deVisitedSite': 0.0,
#  'dayOfTheYear_117deVisitedSite': 0.005270231492291229,
#  'dayOfTheYear_118deVisitedSite': 0.0,
#  'dayOfTheYear_119deVisitedSite': 0.0,
#  'dayOfTheYear_120deVisitedSite': 0.0,
#  'dayOfTheYear_121deVisitedSite': 0.0,
#  'dayOfTheYear_122deVisitedSite': 0.0,
#  'dayOfTheYear_123deVisitedSite': 0.0,
#  'dayOfTheYear_124deVisitedSite': 0.005750381938332067,
#  'dayOfTheYear_125deVisitedSite': 0.0,
#  'dayOfTheYear_126deVisitedSite': 0.0,
#  'dayOfTheYear_127deVisitedSite': 0.0,
#  'dayOfTheYear_128deVisitedSite': 0.0,
#  'dayOfTheYear_129deVisitedSite': 0.0,
#  'dayOfTheYear_130deVisitedSite': 0.0,
#  'dayOfTheYear_131deVisitedSite': 0.0,
#  'dayOfTheYear_132deVisitedSite': 0.0015591425641060103,
#  'dayOfTheYear_133deVisitedSite': 0.0,
#  'dayOfTheYear_134deVisitedSite': 0.0,
#  'dayOfTheYear_135deVisitedSite': 0.0,
#  'dayOfTheYear_136deVisitedSite': 0.0,
#  'dayOfTheYear_137deVisitedSite': 0.0,
#  'dayOfTheYear_138deVisitedSite': 0.0,
#  'dayOfTheYear_139deVisitedSite': 0.0,
#  'dayOfTheYear_140deVisitedSite': 0.0,
#  'dayOfTheYear_141deVisitedSite': 0.0,
#  'dayOfTheYear_142deVisitedSite': 0.0,
#  'dayOfTheYear_143deVisitedSite': 0.0,
#  'dayOfTheYear_144deVisitedSite': 0.0,
#  'dayOfTheYear_145deVisitedSite': 0.0,
#  'dayOfTheYear_146deVisitedSite': 0.0,
#  'dayOfTheYear_147deVisitedSite': 0.0,
#  'dayOfTheYear_148deVisitedSite': 0.0,
#  'dayOfTheYear_149deVisitedSite': 0.0,
#  'dayOfTheYear_150deVisitedSite': 0.0,
#  'dayOfTheYear_151deVisitedSite': 0.0066265187851828125,
#  'dayOfTheYear_1deViewedProduct': 0.0,
#  'dayOfTheYear_2deViewedProduct': 0.0,
#  'dayOfTheYear_3deViewedProduct': 0.0,
#  'dayOfTheYear_4deViewedProduct': 0.0,
#  'dayOfTheYear_5deViewedProduct': 0.0,
#  'dayOfTheYear_6deViewedProduct': 0.0,
#  'dayOfTheYear_7deViewedProduct': 0.0,
#  'dayOfTheYear_8deViewedProduct': 0.0,
#  'dayOfTheYear_9deViewedProduct': 0.0,
#  'dayOfTheYear_10deViewedProduct': 0.0,
#  'dayOfTheYear_11deViewedProduct': 0.0,
#  'dayOfTheYear_12deViewedProduct': 0.0,
#  'dayOfTheYear_13deViewedProduct': 0.0,
#  'dayOfTheYear_14deViewedProduct': 0.0,
#  'dayOfTheYear_15deViewedProduct': 0.0,
#  'dayOfTheYear_16deViewedProduct': 0.0020523610185780015,
#  'dayOfTheYear_17deViewedProduct': 0.0,
#  'dayOfTheYear_18deViewedProduct': 0.0,
#  'dayOfTheYear_19deViewedProduct': 0.0,
#  'dayOfTheYear_20deViewedProduct': 0.0,
#  'dayOfTheYear_21deViewedProduct': 0.0,
#  'dayOfTheYear_22deViewedProduct': 0.0,
#  'dayOfTheYear_23deViewedProduct': 0.0,
#  'dayOfTheYear_24deViewedProduct': 0.0,
#  'dayOfTheYear_25deViewedProduct': 0.0,
#  'dayOfTheYear_26deViewedProduct': 0.0,
#  'dayOfTheYear_27deViewedProduct': 0.0075366565826106655,
#  'dayOfTheYear_28deViewedProduct': 0.0,
#  'dayOfTheYear_29deViewedProduct': 0.0,
#  'dayOfTheYear_30deViewedProduct': 0.0,
#  'dayOfTheYear_31deViewedProduct': 0.0023381831880257328,
#  'dayOfTheYear_32deViewedProduct': 0.0,
#  'dayOfTheYear_33deViewedProduct': 0.0,
#  'dayOfTheYear_34deViewedProduct': 0.0,
#  'dayOfTheYear_35deViewedProduct': 0.0,
#  'dayOfTheYear_36deViewedProduct': 0.004231127662889745,
#  'dayOfTheYear_37deViewedProduct': 0.0,
#  'dayOfTheYear_38deViewedProduct': 0.0,
#  'dayOfTheYear_39deViewedProduct': 0.0,
#  'dayOfTheYear_40deViewedProduct': 0.0,
#  'dayOfTheYear_41deViewedProduct': 0.0,
#  'dayOfTheYear_42deViewedProduct': 0.0,
#  'dayOfTheYear_43deViewedProduct': 0.0,
#  'dayOfTheYear_44deViewedProduct': 0.0,
#  'dayOfTheYear_45deViewedProduct': 0.0,
#  'dayOfTheYear_46deViewedProduct': 0.0,
#  'dayOfTheYear_47deViewedProduct': 0.0,
#  'dayOfTheYear_48deViewedProduct': 0.0,
#  'dayOfTheYear_49deViewedProduct': 0.0,
#  'dayOfTheYear_50deViewedProduct': 0.0,
#  'dayOfTheYear_51deViewedProduct': 0.0,
#  'dayOfTheYear_52deViewedProduct': 0.0,
#  'dayOfTheYear_53deViewedProduct': 0.0,
#  'dayOfTheYear_54deViewedProduct': 0.0,
#  'dayOfTheYear_55deViewedProduct': 0.0,
#  'dayOfTheYear_56deViewedProduct': 0.0018578092977710639,
#  'dayOfTheYear_57deViewedProduct': 0.0,
#  'dayOfTheYear_58deViewedProduct': 0.0,
#  'dayOfTheYear_59deViewedProduct': 0.002855184740151665,
#  'dayOfTheYear_60deViewedProduct': 0.0,
#  'dayOfTheYear_61deViewedProduct': 0.0033989318431291698,
#  'dayOfTheYear_62deViewedProduct': 0.0,
#  'dayOfTheYear_63deViewedProduct': 0.0,
#  'dayOfTheYear_64deViewedProduct': 0.006280211862482257,
#  'dayOfTheYear_65deViewedProduct': 0.0,
#  'dayOfTheYear_66deViewedProduct': 0.0,
#  'dayOfTheYear_67deViewedProduct': 0.0,
#  'dayOfTheYear_68deViewedProduct': 0.0,
#  'dayOfTheYear_69deViewedProduct': 0.0,
#  'dayOfTheYear_70deViewedProduct': 0.0,
#  'dayOfTheYear_71deViewedProduct': 0.0,
#  'dayOfTheYear_72deViewedProduct': 0.0,
#  'dayOfTheYear_73deViewedProduct': 0.0,
#  'dayOfTheYear_74deViewedProduct': 0.0,
#  'dayOfTheYear_75deViewedProduct': 0.0,
#  'dayOfTheYear_76deViewedProduct': 0.0,
#  'dayOfTheYear_77deViewedProduct': 0.004333654412059065,
#  'dayOfTheYear_78deViewedProduct': 0.0,
#  'dayOfTheYear_79deViewedProduct': 0.0,
#  'dayOfTheYear_80deViewedProduct': 0.0,
#  'dayOfTheYear_81deViewedProduct': 0.0,
#  'dayOfTheYear_82deViewedProduct': 0.005228525717449566,
#  'dayOfTheYear_83deViewedProduct': 0.005170452190764837,
#  'dayOfTheYear_84deViewedProduct': 0.0,
#  'dayOfTheYear_85deViewedProduct': 0.0,
#  'dayOfTheYear_86deViewedProduct': 0.0015715081243052942,
#  'dayOfTheYear_87deViewedProduct': 0.0026384043703126265,
#  'dayOfTheYear_88deViewedProduct': 0.0,
#  'dayOfTheYear_89deViewedProduct': 0.004331058615509693,
#  'dayOfTheYear_90deViewedProduct': 0.004269240497848402,
#  'dayOfTheYear_91deViewedProduct': 0.0,
#  'dayOfTheYear_92deViewedProduct': 0.0029885207007983635,
#  'dayOfTheYear_93deViewedProduct': 0.0,
#  'dayOfTheYear_94deViewedProduct': 0.0,
#  'dayOfTheYear_95deViewedProduct': 0.003964690701047268,
#  'dayOfTheYear_96deViewedProduct': 0.0,
#  'dayOfTheYear_97deViewedProduct': 0.0,
#  'dayOfTheYear_98deViewedProduct': 0.0,
#  'dayOfTheYear_99deViewedProduct': 0.0,
#  'dayOfTheYear_100deViewedProduct': 0.0,
#  'dayOfTheYear_101deViewedProduct': 0.0,
#  'dayOfTheYear_102deViewedProduct': 0.0,
#  'dayOfTheYear_103deViewedProduct': 0.0,
#  'dayOfTheYear_104deViewedProduct': 0.0,
#  'dayOfTheYear_105deViewedProduct': 0.0008110543024104648,
#  'dayOfTheYear_106deViewedProduct': 0.0,
#  'dayOfTheYear_107deViewedProduct': 0.0,
#  'dayOfTheYear_108deViewedProduct': 0.0,
#  'dayOfTheYear_109deViewedProduct': 0.0,
#  'dayOfTheYear_110deViewedProduct': 0.00312443144103245,
#  'dayOfTheYear_111deViewedProduct': 0.0,
#  'dayOfTheYear_112deViewedProduct': 0.0,
#  'dayOfTheYear_113deViewedProduct': 0.005857824674531682,
#  'dayOfTheYear_114deViewedProduct': 0.0,
#  'dayOfTheYear_115deViewedProduct': 0.0,
#  'dayOfTheYear_116deViewedProduct': 0.0,
#  'dayOfTheYear_117deViewedProduct': 0.0,
#  'dayOfTheYear_118deViewedProduct': 0.0,
#  'dayOfTheYear_119deViewedProduct': 0.0,
#  'dayOfTheYear_120deViewedProduct': 0.003172008801320299,
#  'dayOfTheYear_121deViewedProduct': 0.0,
#  'dayOfTheYear_122deViewedProduct': 0.00487472363296355,
#  'dayOfTheYear_123deViewedProduct': 0.0,
#  'dayOfTheYear_124deViewedProduct': 0.0,
#  'dayOfTheYear_125deViewedProduct': 0.0,
#  'dayOfTheYear_126deViewedProduct': 0.0,
#  'dayOfTheYear_127deViewedProduct': 0.0,
#  'dayOfTheYear_128deViewedProduct': 0.0025126550749253653,
#  'dayOfTheYear_129deViewedProduct': 0.0,
#  'dayOfTheYear_130deViewedProduct': 0.0,
#  'dayOfTheYear_131deViewedProduct': 0.0,
#  'dayOfTheYear_132deViewedProduct': 0.0,
#  'dayOfTheYear_133deViewedProduct': 0.004904155298598667,
#  'dayOfTheYear_134deViewedProduct': 0.0,
#  'dayOfTheYear_135deViewedProduct': 0.0,
#  'dayOfTheYear_136deViewedProduct': 0.0,
#  'dayOfTheYear_137deViewedProduct': 0.0,
#  'dayOfTheYear_138deViewedProduct': 0.0,
#  'dayOfTheYear_139deViewedProduct': 0.0,
#  'dayOfTheYear_140deViewedProduct': 0.0,
#  'dayOfTheYear_141deViewedProduct': 0.0,
#  'dayOfTheYear_142deViewedProduct': 0.0,
#  'dayOfTheYear_143deViewedProduct': 0.0,
#  'dayOfTheYear_144deViewedProduct': 0.0,
#  'dayOfTheYear_145deViewedProduct': 0.0,
#  'dayOfTheYear_146deViewedProduct': 0.0,
#  'dayOfTheYear_147deViewedProduct': 0.0,
#  'dayOfTheYear_148deViewedProduct': 0.0,
#  'dayOfTheYear_149deViewedProduct': 0.001533992411406016,
#  'dayOfTheYear_150deViewedProduct': 0.0,
#  'dayOfTheYear_151deViewedProduct': 0.013744059020141404,
#  'dayOfTheYear_1deSearchedProduct': 0.0,
#  'dayOfTheYear_2deSearchedProduct': 0.0,
#  'dayOfTheYear_3deSearchedProduct': 0.0,
#  'dayOfTheYear_4deSearchedProduct': 0.0,
#  'dayOfTheYear_5deSearchedProduct': 0.0,
#  'dayOfTheYear_6deSearchedProduct': 0.0,
#  'dayOfTheYear_7deSearchedProduct': 0.0,
#  'dayOfTheYear_8deSearchedProduct': 0.0,
#  'dayOfTheYear_9deSearchedProduct': 0.0,
#  'dayOfTheYear_10deSearchedProduct': 0.0,
#  'dayOfTheYear_11deSearchedProduct': 0.0,
#  'dayOfTheYear_12deSearchedProduct': 0.0,
#  'dayOfTheYear_13deSearchedProduct': 0.0,
#  'dayOfTheYear_14deSearchedProduct': 0.0,
#  'dayOfTheYear_15deSearchedProduct': 0.0,
#  'dayOfTheYear_16deSearchedProduct': 0.0,
#  'dayOfTheYear_17deSearchedProduct': 0.0,
#  'dayOfTheYear_18deSearchedProduct': 0.0,
#  'dayOfTheYear_19deSearchedProduct': 0.0,
#  'dayOfTheYear_20deSearchedProduct': 0.0,
#  'dayOfTheYear_21deSearchedProduct': 0.0,
#  'dayOfTheYear_22deSearchedProduct': 0.0,
#  'dayOfTheYear_23deSearchedProduct': 0.0,
#  'dayOfTheYear_24deSearchedProduct': 0.0,
#  'dayOfTheYear_25deSearchedProduct': 0.0,
#  'dayOfTheYear_26deSearchedProduct': 0.0,
#  'dayOfTheYear_27deSearchedProduct': 0.0,
#  'dayOfTheYear_28deSearchedProduct': 0.0,
#  'dayOfTheYear_29deSearchedProduct': 0.0,
#  'dayOfTheYear_30deSearchedProduct': 0.0,
#  'dayOfTheYear_31deSearchedProduct': 0.0,
#  'dayOfTheYear_32deSearchedProduct': 0.0,
#  'dayOfTheYear_33deSearchedProduct': 0.0,
#  'dayOfTheYear_34deSearchedProduct': 0.0,
#  'dayOfTheYear_35deSearchedProduct': 0.0,
#  'dayOfTheYear_36deSearchedProduct': 0.0,
#  'dayOfTheYear_37deSearchedProduct': 0.0,
#  'dayOfTheYear_38deSearchedProduct': 0.0,
#  'dayOfTheYear_39deSearchedProduct': 0.0,
#  'dayOfTheYear_40deSearchedProduct': 0.0,
#  'dayOfTheYear_41deSearchedProduct': 0.0,
#  'dayOfTheYear_42deSearchedProduct': 0.0,
#  'dayOfTheYear_43deSearchedProduct': 0.0,
#  'dayOfTheYear_44deSearchedProduct': 0.0,
#  'dayOfTheYear_45deSearchedProduct': 0.0,
#  'dayOfTheYear_46deSearchedProduct': 0.0,
#  'dayOfTheYear_47deSearchedProduct': 0.0,
#  'dayOfTheYear_48deSearchedProduct': 0.0,
#  'dayOfTheYear_49deSearchedProduct': 0.0,
#  'dayOfTheYear_50deSearchedProduct': 0.0,
#  'dayOfTheYear_51deSearchedProduct': 0.0,
#  'dayOfTheYear_52deSearchedProduct': 0.0,
#  'dayOfTheYear_53deSearchedProduct': 0.0,
#  'dayOfTheYear_54deSearchedProduct': 0.0,
#  'dayOfTheYear_55deSearchedProduct': 0.0,
#  'dayOfTheYear_56deSearchedProduct': 0.0028473286116049244,
#  'dayOfTheYear_57deSearchedProduct': 0.0,
#  'dayOfTheYear_58deSearchedProduct': 0.0,
#  'dayOfTheYear_59deSearchedProduct': 0.0,
#  'dayOfTheYear_60deSearchedProduct': 0.00018811385906498653,
#  'dayOfTheYear_61deSearchedProduct': 0.0,
#  'dayOfTheYear_62deSearchedProduct': 0.0,
#  'dayOfTheYear_63deSearchedProduct': 0.0027737662195110825,
#  'dayOfTheYear_64deSearchedProduct': 0.009973601200343834,
#  'dayOfTheYear_65deSearchedProduct': 0.0,
#  'dayOfTheYear_66deSearchedProduct': 0.0030764001607534153,
#  'dayOfTheYear_67deSearchedProduct': 0.0,
#  'dayOfTheYear_68deSearchedProduct': 0.0037556027573601193,
#  'dayOfTheYear_69deSearchedProduct': 0.0,
#  'dayOfTheYear_70deSearchedProduct': 0.0,
#  'dayOfTheYear_71deSearchedProduct': 0.0,
#  'dayOfTheYear_72deSearchedProduct': 0.002566783632529345,
#  'dayOfTheYear_73deSearchedProduct': 0.0,
#  'dayOfTheYear_74deSearchedProduct': 0.00026605539821113167,
#  'dayOfTheYear_75deSearchedProduct': 0.0,
#  'dayOfTheYear_76deSearchedProduct': 0.0,
#  'dayOfTheYear_77deSearchedProduct': 0.0,
#  'dayOfTheYear_78deSearchedProduct': 0.0,
#  'dayOfTheYear_79deSearchedProduct': 0.0,
#  'dayOfTheYear_80deSearchedProduct': 0.0,
#  'dayOfTheYear_81deSearchedProduct': 0.0,
#  'dayOfTheYear_82deSearchedProduct': 0.0,
#  'dayOfTheYear_83deSearchedProduct': 0.008857414994411564,
#  'dayOfTheYear_84deSearchedProduct': 0.005180451643591239,
#  'dayOfTheYear_85deSearchedProduct': 0.0,
#  'dayOfTheYear_86deSearchedProduct': 0.0029000152339459,
#  'dayOfTheYear_87deSearchedProduct': 0.0,
#  'dayOfTheYear_88deSearchedProduct': 0.0,
#  'dayOfTheYear_89deSearchedProduct': 0.002699145657790945,
#  'dayOfTheYear_90deSearchedProduct': 0.0,
#  'dayOfTheYear_91deSearchedProduct': 0.0,
#  'dayOfTheYear_92deSearchedProduct': 0.008424035430000252,
#  'dayOfTheYear_93deSearchedProduct': 0.008227545387584712,
#  'dayOfTheYear_94deSearchedProduct': 0.0010892435424211242,
#  'dayOfTheYear_95deSearchedProduct': 0.011513477368867854,
#  'dayOfTheYear_96deSearchedProduct': 0.007437694977808864,
#  'dayOfTheYear_97deSearchedProduct': 0.003989278156627266,
#  'dayOfTheYear_98deSearchedProduct': 0.0,
#  'dayOfTheYear_99deSearchedProduct': 0.0,
#  'dayOfTheYear_100deSearchedProduct': 0.0,
#  'dayOfTheYear_101deSearchedProduct': 0.0,
#  'dayOfTheYear_102deSearchedProduct': 0.0023797021933932207,
#  'dayOfTheYear_103deSearchedProduct': 0.0,
#  'dayOfTheYear_104deSearchedProduct': 0.0,
#  'dayOfTheYear_105deSearchedProduct': 0.0,
#  'dayOfTheYear_106deSearchedProduct': 0.0,
#  'dayOfTheYear_107deSearchedProduct': 0.0,
#  'dayOfTheYear_108deSearchedProduct': 0.0,
#  'dayOfTheYear_109deSearchedProduct': 0.0,
#  'dayOfTheYear_110deSearchedProduct': 0.0018568441457639596,
#  'dayOfTheYear_111deSearchedProduct': 0.0,
#  'dayOfTheYear_112deSearchedProduct': 0.0,
#  'dayOfTheYear_113deSearchedProduct': 0.0055610909310039956,
#  'dayOfTheYear_114deSearchedProduct': 0.0,
#  'dayOfTheYear_115deSearchedProduct': 0.0,
#  'dayOfTheYear_116deSearchedProduct': 0.0,
#  'dayOfTheYear_117deSearchedProduct': 0.0,
#  'dayOfTheYear_118deSearchedProduct': 0.0,
#  'dayOfTheYear_119deSearchedProduct': 0.0,
#  'dayOfTheYear_120deSearchedProduct': 0.0,
#  'dayOfTheYear_121deSearchedProduct': 0.0,
#  'dayOfTheYear_122deSearchedProduct': 0.004596525868950928,
#  'dayOfTheYear_123deSearchedProduct': 0.001097810194947426,
#  'dayOfTheYear_124deSearchedProduct': 0.0,
#  'dayOfTheYear_125deSearchedProduct': 0.0,
#  'dayOfTheYear_126deSearchedProduct': 0.0,
#  'dayOfTheYear_127deSearchedProduct': 0.0,
#  'dayOfTheYear_128deSearchedProduct': 0.0,
#  'dayOfTheYear_129deSearchedProduct': 0.0,
#  'dayOfTheYear_130deSearchedProduct': 0.0,
#  'dayOfTheYear_131deSearchedProduct': 0.0,
#  'dayOfTheYear_132deSearchedProduct': 0.0,
#  'dayOfTheYear_133deSearchedProduct': 0.0,
#  'dayOfTheYear_134deSearchedProduct': 0.0,
#  'dayOfTheYear_135deSearchedProduct': 0.0,
#  'dayOfTheYear_136deSearchedProduct': 0.0,
#  'dayOfTheYear_137deSearchedProduct': 0.0,
#  'dayOfTheYear_138deSearchedProduct': 0.0,
#  'dayOfTheYear_139deSearchedProduct': 0.0,
#  'dayOfTheYear_140deSearchedProduct': 0.005751356544319939,
#  'dayOfTheYear_141deSearchedProduct': 0.0,
#  'dayOfTheYear_142deSearchedProduct': 0.0,
#  'dayOfTheYear_143deSearchedProduct': 0.0,
#  'dayOfTheYear_144deSearchedProduct': 0.0006302302117961669,
#  'dayOfTheYear_145deSearchedProduct': 0.0013821871062554786,
#  'dayOfTheYear_146deSearchedProduct': 0.0,
#  'dayOfTheYear_147deSearchedProduct': 0.0,
#  'dayOfTheYear_148deSearchedProduct': 0.0,
#  'dayOfTheYear_149deSearchedProduct': 0.0,
#  'dayOfTheYear_150deSearchedProduct': 0.0,
#  'dayOfTheYear_151deSearchedProduct': 0.0,
#  'dayOfTheYear_1deAdCampaignHit': 0.0,
#  'dayOfTheYear_2deAdCampaignHit': 0.0,
#  'dayOfTheYear_3deAdCampaignHit': 0.0,
#  'dayOfTheYear_4deAdCampaignHit': 0.0,
#  'dayOfTheYear_5deAdCampaignHit': 0.0,
#  'dayOfTheYear_6deAdCampaignHit': 0.0,
#  'dayOfTheYear_7deAdCampaignHit': 0.0,
#  'dayOfTheYear_8deAdCampaignHit': 0.0,
#  'dayOfTheYear_9deAdCampaignHit': 0.0,
#  'dayOfTheYear_10deAdCampaignHit': 0.0027477228989784565,
#  'dayOfTheYear_11deAdCampaignHit': 0.0,
#  'dayOfTheYear_12deAdCampaignHit': 0.0,
#  'dayOfTheYear_13deAdCampaignHit': 0.0,
#  'dayOfTheYear_14deAdCampaignHit': 0.0,
#  'dayOfTheYear_15deAdCampaignHit': 0.0,
#  'dayOfTheYear_16deAdCampaignHit': 0.0,
#  'dayOfTheYear_17deAdCampaignHit': 0.0,
#  'dayOfTheYear_18deAdCampaignHit': 0.0,
#  'dayOfTheYear_19deAdCampaignHit': 0.0,
#  'dayOfTheYear_20deAdCampaignHit': 0.0,
#  'dayOfTheYear_21deAdCampaignHit': 0.0,
#  'dayOfTheYear_22deAdCampaignHit': 0.0,
#  'dayOfTheYear_23deAdCampaignHit': 0.0,
#  'dayOfTheYear_24deAdCampaignHit': 0.0,
#  'dayOfTheYear_25deAdCampaignHit': 0.0,
#  'dayOfTheYear_26deAdCampaignHit': 0.0,
#  'dayOfTheYear_27deAdCampaignHit': 0.0,
#  'dayOfTheYear_28deAdCampaignHit': 0.0,
#  'dayOfTheYear_29deAdCampaignHit': 0.0,
#  'dayOfTheYear_30deAdCampaignHit': 0.0050149233656943395,
#  'dayOfTheYear_31deAdCampaignHit': 0.0,
#  'dayOfTheYear_32deAdCampaignHit': 0.0,
#  'dayOfTheYear_33deAdCampaignHit': 0.0,
#  'dayOfTheYear_34deAdCampaignHit': 0.0020820958679738694,
#  'dayOfTheYear_35deAdCampaignHit': 0.0,
#  'dayOfTheYear_36deAdCampaignHit': 0.0,
#  'dayOfTheYear_37deAdCampaignHit': 0.0,
#  'dayOfTheYear_38deAdCampaignHit': 0.0,
#  'dayOfTheYear_39deAdCampaignHit': 0.0,
#  'dayOfTheYear_40deAdCampaignHit': 0.0,
#  'dayOfTheYear_41deAdCampaignHit': 0.0,
#  'dayOfTheYear_42deAdCampaignHit': 0.0,
#  'dayOfTheYear_43deAdCampaignHit': 0.0,
#  'dayOfTheYear_44deAdCampaignHit': 0.0,
#  'dayOfTheYear_45deAdCampaignHit': 0.003417838731037848,
#  'dayOfTheYear_46deAdCampaignHit': 0.0,
#  'dayOfTheYear_47deAdCampaignHit': 0.0,
#  'dayOfTheYear_48deAdCampaignHit': 0.0,
#  'dayOfTheYear_49deAdCampaignHit': 0.0,
#  'dayOfTheYear_50deAdCampaignHit': 0.0,
#  'dayOfTheYear_51deAdCampaignHit': 0.0,
#  'dayOfTheYear_52deAdCampaignHit': 0.0,
#  'dayOfTheYear_53deAdCampaignHit': 0.0,
#  'dayOfTheYear_54deAdCampaignHit': 0.0,
#  'dayOfTheYear_55deAdCampaignHit': 0.0,
#  'dayOfTheYear_56deAdCampaignHit': 0.0,
#  'dayOfTheYear_57deAdCampaignHit': 0.0,
#  'dayOfTheYear_58deAdCampaignHit': 0.0,
#  'dayOfTheYear_59deAdCampaignHit': 0.0,
#  'dayOfTheYear_60deAdCampaignHit': 0.0,
#  'dayOfTheYear_61deAdCampaignHit': 0.0,
#  'dayOfTheYear_62deAdCampaignHit': 0.0,
#  'dayOfTheYear_63deAdCampaignHit': 0.0,
#  'dayOfTheYear_64deAdCampaignHit': 0.0025254658449302587,
#  'dayOfTheYear_65deAdCampaignHit': 0.0,
#  'dayOfTheYear_66deAdCampaignHit': 0.001962235754089228,
#  'dayOfTheYear_67deAdCampaignHit': 0.0,
#  'dayOfTheYear_68deAdCampaignHit': 0.0,
#  'dayOfTheYear_69deAdCampaignHit': 0.0,
#  'dayOfTheYear_70deAdCampaignHit': 0.0,
#  'dayOfTheYear_71deAdCampaignHit': 0.0,
#  'dayOfTheYear_72deAdCampaignHit': 0.0,
#  'dayOfTheYear_73deAdCampaignHit': 0.0,
#  'dayOfTheYear_74deAdCampaignHit': 0.0,
#  'dayOfTheYear_75deAdCampaignHit': 0.0,
#  'dayOfTheYear_76deAdCampaignHit': 0.0,
#  'dayOfTheYear_77deAdCampaignHit': 0.0,
#  'dayOfTheYear_78deAdCampaignHit': 0.004176415231335881,
#  'dayOfTheYear_79deAdCampaignHit': 0.0,
#  'dayOfTheYear_80deAdCampaignHit': 0.0,
#  'dayOfTheYear_81deAdCampaignHit': 0.004536927843238238,
#  'dayOfTheYear_82deAdCampaignHit': 0.000373253647787686,
#  'dayOfTheYear_83deAdCampaignHit': 0.0,
#  'dayOfTheYear_84deAdCampaignHit': 0.006831372257113292,
#  'dayOfTheYear_85deAdCampaignHit': 0.0,
#  'dayOfTheYear_86deAdCampaignHit': 0.0,
#  'dayOfTheYear_87deAdCampaignHit': 0.0,
#  'dayOfTheYear_88deAdCampaignHit': 0.0,
#  'dayOfTheYear_89deAdCampaignHit': 0.0,
#  'dayOfTheYear_90deAdCampaignHit': 0.0,
#  'dayOfTheYear_91deAdCampaignHit': 0.0038729502043805338,
#  'dayOfTheYear_92deAdCampaignHit': 0.003735720367178518,
#  'dayOfTheYear_93deAdCampaignHit': 0.0,
#  'dayOfTheYear_94deAdCampaignHit': 0.0,
#  'dayOfTheYear_95deAdCampaignHit': 0.002598264240271711,
#  'dayOfTheYear_96deAdCampaignHit': 0.0036423446585061993,
#  'dayOfTheYear_97deAdCampaignHit': 0.0,
#  'dayOfTheYear_98deAdCampaignHit': 0.0,
#  'dayOfTheYear_99deAdCampaignHit': 0.0,
#  'dayOfTheYear_100deAdCampaignHit': 0.004143348326375148,
#  'dayOfTheYear_101deAdCampaignHit': 0.004021551489556535,
#  'dayOfTheYear_102deAdCampaignHit': 0.0,
#  'dayOfTheYear_103deAdCampaignHit': 0.0,
#  'dayOfTheYear_104deAdCampaignHit': 0.004896505336747311,
#  'dayOfTheYear_105deAdCampaignHit': 0.0,
#  'dayOfTheYear_106deAdCampaignHit': 0.0,
#  'dayOfTheYear_107deAdCampaignHit': 0.0,
#  'dayOfTheYear_108deAdCampaignHit': 0.0,
#  'dayOfTheYear_109deAdCampaignHit': 0.0,
#  'dayOfTheYear_110deAdCampaignHit': 0.003885055628578048,
#  'dayOfTheYear_111deAdCampaignHit': 0.0,
#  'dayOfTheYear_112deAdCampaignHit': 0.0,
#  'dayOfTheYear_113deAdCampaignHit': 0.0020458521704614326,
#  'dayOfTheYear_114deAdCampaignHit': 0.0038237675298330755,
#  'dayOfTheYear_115deAdCampaignHit': 0.0,
#  'dayOfTheYear_116deAdCampaignHit': 0.0,
#  'dayOfTheYear_117deAdCampaignHit': 0.0027824123296734337,
#  'dayOfTheYear_118deAdCampaignHit': 0.0,
#  'dayOfTheYear_119deAdCampaignHit': 0.0,
#  'dayOfTheYear_120deAdCampaignHit': 0.0,
#  'dayOfTheYear_121deAdCampaignHit': 0.0021095649210809255,
#  'dayOfTheYear_122deAdCampaignHit': 0.0,
#  'dayOfTheYear_123deAdCampaignHit': 0.0,
#  'dayOfTheYear_124deAdCampaignHit': 0.0,
#  'dayOfTheYear_125deAdCampaignHit': 0.0,
#  'dayOfTheYear_126deAdCampaignHit': 0.0021890705225250007,
#  'dayOfTheYear_127deAdCampaignHit': 0.0,
#  'dayOfTheYear_128deAdCampaignHit': 0.0,
#  'dayOfTheYear_129deAdCampaignHit': 0.0,
#  'dayOfTheYear_130deAdCampaignHit': 0.0,
#  'dayOfTheYear_131deAdCampaignHit': 0.0,
#  'dayOfTheYear_132deAdCampaignHit': 0.0,
#  'dayOfTheYear_133deAdCampaignHit': 0.0,
#  'dayOfTheYear_134deAdCampaignHit': 0.0,
#  'dayOfTheYear_135deAdCampaignHit': 0.0,
#  'dayOfTheYear_136deAdCampaignHit': 0.0,
#  'dayOfTheYear_137deAdCampaignHit': 0.0,
#  'dayOfTheYear_138deAdCampaignHit': 0.0,
#  'dayOfTheYear_139deAdCampaignHit': 0.0,
#  'dayOfTheYear_140deAdCampaignHit': 0.0,
#  'dayOfTheYear_141deAdCampaignHit': 0.0,
#  'dayOfTheYear_142deAdCampaignHit': 0.0,
#  'dayOfTheYear_143deAdCampaignHit': 0.0,
#  'dayOfTheYear_144deAdCampaignHit': 0.0,
#  'dayOfTheYear_145deAdCampaignHit': 0.0,
#  'dayOfTheYear_146deAdCampaignHit': 0.0,
#  'dayOfTheYear_147deAdCampaignHit': 0.0,
#  'dayOfTheYear_148deAdCampaignHit': 0.0,
#  'dayOfTheYear_149deAdCampaignHit': 0.0013673267511493037,
#  'dayOfTheYear_150deAdCampaignHit': 0.004400785261797199,
#  'dayOfTheYear_151deAdCampaignHit': 0.0032456287855607696,
#  'dayOfTheYear_1brandListing': 0.002388643900878409,
#  'dayOfTheYear_2brandListing': 0.0,
#  'dayOfTheYear_3brandListing': 0.0,
#  'dayOfTheYear_4brandListing': 0.0,
#  'dayOfTheYear_5brandListing': 0.0,
#  'dayOfTheYear_6brandListing': 0.0,
#  'dayOfTheYear_7brandListing': 0.0,
#  'dayOfTheYear_8brandListing': 0.0,
#  'dayOfTheYear_9brandListing': 0.0,
#  'dayOfTheYear_10brandListing': 0.0,
#  'dayOfTheYear_11brandListing': 0.0,
#  'dayOfTheYear_12brandListing': 0.0,
#  'dayOfTheYear_13brandListing': 0.0,
#  'dayOfTheYear_14brandListing': 0.0,
#  'dayOfTheYear_15brandListing': 0.0,
#  'dayOfTheYear_16brandListing': 0.0,
#  'dayOfTheYear_17brandListing': 0.0,
#  'dayOfTheYear_18brandListing': 0.0,
#  'dayOfTheYear_19brandListing': 0.0,
#  'dayOfTheYear_20brandListing': 0.0,
#  'dayOfTheYear_21brandListing': 0.0,
#  'dayOfTheYear_22brandListing': 0.0,
#  'dayOfTheYear_23brandListing': 0.0,
#  'dayOfTheYear_24brandListing': 0.0,
#  'dayOfTheYear_25brandListing': 0.0,
#  'dayOfTheYear_26brandListing': 0.0,
#  'dayOfTheYear_27brandListing': 0.00498507663430566,
#  'dayOfTheYear_28brandListing': 0.0,
#  'dayOfTheYear_29brandListing': 0.0,
#  'dayOfTheYear_30brandListing': 0.0,
#  'dayOfTheYear_31brandListing': 0.0055013166417187224,
#  'dayOfTheYear_32brandListing': 0.0,
#  'dayOfTheYear_33brandListing': 0.0,
#  'dayOfTheYear_34brandListing': 0.003812121350731677,
#  'dayOfTheYear_35brandListing': 0.0,
#  'dayOfTheYear_36brandListing': 0.0,
#  'dayOfTheYear_37brandListing': 0.0,
#  'dayOfTheYear_38brandListing': 0.0,
#  'dayOfTheYear_39brandListing': 0.0,
#  'dayOfTheYear_40brandListing': 0.0,
#  'dayOfTheYear_41brandListing': 0.0,
#  'dayOfTheYear_42brandListing': 0.0,
#  'dayOfTheYear_43brandListing': 0.0,
#  'dayOfTheYear_44brandListing': 0.0,
#  'dayOfTheYear_45brandListing': 0.0,
#  'dayOfTheYear_46brandListing': 0.0,
#  'dayOfTheYear_47brandListing': 0.0,
#  'dayOfTheYear_48brandListing': 0.0,
#  'dayOfTheYear_49brandListing': 0.0,
#  'dayOfTheYear_50brandListing': 0.0,
#  'dayOfTheYear_51brandListing': 0.0,
#  'dayOfTheYear_52brandListing': 0.0,
#  'dayOfTheYear_53brandListing': 0.0,
#  'dayOfTheYear_54brandListing': 0.0,
#  'dayOfTheYear_55brandListing': 0.0,
#  'dayOfTheYear_56brandListing': 0.0,
#  'dayOfTheYear_57brandListing': 0.0,
#  'dayOfTheYear_58brandListing': 0.0,
#  'dayOfTheYear_59brandListing': 0.0,
#  'dayOfTheYear_60brandListing': 0.0,
#  'dayOfTheYear_61brandListing': 0.0,
#  'dayOfTheYear_62brandListing': 0.0,
#  'dayOfTheYear_63brandListing': 0.0,
#  'dayOfTheYear_64brandListing': 0.0,
#  'dayOfTheYear_65brandListing': 0.003633794062159483,
#  'dayOfTheYear_66brandListing': 0.0,
#  'dayOfTheYear_67brandListing': 0.0,
#  'dayOfTheYear_68brandListing': 0.0,
#  'dayOfTheYear_69brandListing': 0.0,
#  'dayOfTheYear_70brandListing': 0.0,
#  'dayOfTheYear_71brandListing': 0.0,
#  'dayOfTheYear_72brandListing': 0.0,
#  'dayOfTheYear_73brandListing': 0.0,
#  'dayOfTheYear_74brandListing': 0.0,
#  'dayOfTheYear_75brandListing': 0.0,
#  'dayOfTheYear_76brandListing': 0.0,
#  'dayOfTheYear_77brandListing': 0.0,
#  'dayOfTheYear_78brandListing': 0.0,
#  'dayOfTheYear_79brandListing': 0.0,
#  'dayOfTheYear_80brandListing': 0.0,
#  'dayOfTheYear_81brandListing': 0.0,
#  'dayOfTheYear_82brandListing': 0.0,
#  'dayOfTheYear_83brandListing': 0.0,
#  'dayOfTheYear_84brandListing': 0.012260093248328994,
#  'dayOfTheYear_85brandListing': 0.0027255258395143373,
#  'dayOfTheYear_86brandListing': 0.004729768507708772,
#  'dayOfTheYear_87brandListing': 0.0,
#  'dayOfTheYear_88brandListing': 0.005984924617418162,
#  'dayOfTheYear_89brandListing': 0.0034615676903964696,
#  'dayOfTheYear_90brandListing': 0.002381157879336435,
#  'dayOfTheYear_91brandListing': 0.0031313566071319737,
#  'dayOfTheYear_92brandListing': 0.004305669999513653,
#  'dayOfTheYear_93brandListing': 0.0,
#  'dayOfTheYear_94brandListing': 0.009858161693851085,
#  'dayOfTheYear_95brandListing': 0.0,
#  'dayOfTheYear_96brandListing': 0.0,
#  'dayOfTheYear_97brandListing': 0.005644177654774659,
#  'dayOfTheYear_98brandListing': 0.0,
#  'dayOfTheYear_99brandListing': 0.0,
#  'dayOfTheYear_100brandListing': 0.0,
#  'dayOfTheYear_101brandListing': 0.0,
#  'dayOfTheYear_102brandListing': 0.0,
#  'dayOfTheYear_103brandListing': 0.0,
#  'dayOfTheYear_104brandListing': 0.0,
#  'dayOfTheYear_105brandListing': 0.0,
#  'dayOfTheYear_106brandListing': 0.002201014348729632,
#  'dayOfTheYear_107brandListing': 0.0,
#  'dayOfTheYear_108brandListing': 0.0,
#  'dayOfTheYear_109brandListing': 0.003575209994835408,
#  'dayOfTheYear_110brandListing': 0.0,
#  'dayOfTheYear_111brandListing': 0.0,
#  'dayOfTheYear_112brandListing': 0.003258853549256668,
#  'dayOfTheYear_113brandListing': 0.0,
#  'dayOfTheYear_114brandListing': 0.0,
#  'dayOfTheYear_115brandListing': 0.0,
#  'dayOfTheYear_116brandListing': 0.0,
#  'dayOfTheYear_117brandListing': 0.0,
#  'dayOfTheYear_118brandListing': 0.0,
#  'dayOfTheYear_119brandListing': 0.0,
#  'dayOfTheYear_120brandListing': 0.0,
#  'dayOfTheYear_121brandListing': 0.0,
#  'dayOfTheYear_122brandListing': 0.0,
#  'dayOfTheYear_123brandListing': 0.0,
#  'dayOfTheYear_124brandListing': 0.0,
#  'dayOfTheYear_125brandListing': 0.0,
#  'dayOfTheYear_126brandListing': 0.0,
#  'dayOfTheYear_127brandListing': 0.002313432371727899,
#  'dayOfTheYear_128brandListing': 0.007968586946038697,
#  'dayOfTheYear_129brandListing': 0.0,
#  'dayOfTheYear_130brandListing': 0.0,
#  'dayOfTheYear_131brandListing': 0.0,
#  'dayOfTheYear_132brandListing': 0.0,
#  'dayOfTheYear_133brandListing': 0.0,
#  'dayOfTheYear_134brandListing': 0.0,
#  'dayOfTheYear_135brandListing': 0.0,
#  'dayOfTheYear_136brandListing': 0.0,
#  'dayOfTheYear_137brandListing': 0.0,
#  'dayOfTheYear_138brandListing': 0.0,
#  'dayOfTheYear_139brandListing': 0.0,
#  'dayOfTheYear_140brandListing': 0.0009119565364359686,
#  'dayOfTheYear_141brandListing': 0.0,
#  ...}

# %%
atributos_importantes = []
for clave in importancia_con_nombre.keys():
    if importancia_con_nombre[clave] > 0:
        atributos_importantes.append(clave)

# %%
atributos_importantes
# Out:
# ['esNuevo',
#  'cantidadDeVisitas',
#  'buscape',
#  'criteo',
#  'google',
#  'rtbhouse',
#  'cantVisitasAVP',
#  'tarde',
#  'noche',
#  'cantDirect',
#  'cantOrganic',
#  'cantReferral',
#  'cantVisitasDomingo',
#  'cantVisitasLunes',
#  'cantVisitasMartes',
#  'cantVisitasMiercoles',
#  'cantVisitasJueves',
#  'cantidadDeEventos',
#  'cantAdCampaignHit',
#  'cantBandListing',
#  'cantCheckout',
#  'cantGenericListing',
#  'cantSearchEngineHit',
#  'cantSearchedProducts',
#  'cantViewedProduct',
#  'cantVisitedSite',
#  'visitaALaTarde',
#  'canalDirect',
#  'canalRefferal',
#  'bandListing',
#  'checkout',
#  'genericListing',
#  'searchEngineHit',
#  'index',
#  'dayOfTheYear_37deCheckout',
#  'dayOfTheYear_39deCheckout',
#  'dayOfTheYear_56deCheckout',
#  'dayOfTheYear_72deCheckout',
#  'dayOfTheYear_80deCheckout',
#  'dayOfTheYear_82deCheckout',
#  'dayOfTheYear_93deCheckout',
#  'dayOfTheYear_109deCheckout',
#  'dayOfTheYear_115deCheckout',
#  'dayOfTheYear_123deCheckout',
#  'dayOfTheYear_132deCheckout',
#  'dayOfTheYear_135deCheckout',
#  'dayOfTheYear_141deCheckout',
#  'dayOfTheYear_149deCheckout',
#  'dayOfTheYear_151deCheckout',
#  'dayOfTheYear_10deVisitedSite',
#  'dayOfTheYear_23deVisitedSite',
#  'dayOfTheYear_68deVisitedSite',
#  'dayOfTheYear_80deVisitedSite',
#  'dayOfTheYear_81deVisitedSite',
#  'dayOfTheYear_89deVisitedSite',
#  'dayOfTheYear_92deVisitedSite',
#  'dayOfTheYear_97deVisitedSite',
#  'dayOfTheYear_98deVisitedSite',
#  'dayOfTheYear_103deVisitedSite',
#  'dayOfTheYear_109deVisitedSite',
#  'dayOfTheYear_110deVisitedSite',
#  'dayOfTheYear_113deVisitedSite',
#  'dayOfTheYear_114deVisitedSite',
#  'dayOfTheYear_115deVisitedSite',
#  'dayOfTheYear_117deVisitedSite',
#  'dayOfTheYear_124deVisitedSite',
#  'dayOfTheYear_132deVisitedSite',
#  'dayOfTheYear_151deVisitedSite',
#  'dayOfTheYear_16deViewedProduct',
#  'dayOfTheYear_27deViewedProduct',
#  'dayOfTheYear_31deViewedProduct',
#  'dayOfTheYear_36deViewedProduct',
#  'dayOfTheYear_56deViewedProduct',
#  'dayOfTheYear_59deViewedProduct',
#  'dayOfTheYear_61deViewedProduct',
#  'dayOfTheYear_64deViewedProduct',
#  'dayOfTheYear_77deViewedProduct',
#  'dayOfTheYear_82deViewedProduct',
#  'dayOfTheYear_83deViewedProduct',
#  'dayOfTheYear_86deViewedProduct',
#  'dayOfTheYear_87deViewedProduct',
#  'dayOfTheYear_89deViewedProduct',
#  'dayOfTheYear_90deViewedProduct',
#  'dayOfTheYear_92deViewedProduct',
#  'dayOfTheYear_95deViewedProduct',
#  'dayOfTheYear_105deViewedProduct',
#  'dayOfTheYear_110deViewedProduct',
#  'dayOfTheYear_113deViewedProduct',
#  'dayOfTheYear_120deViewedProduct',
#  'dayOfTheYear_122deViewedProduct',
#  'dayOfTheYear_128deViewedProduct',
#  'dayOfTheYear_133deViewedProduct',
#  'dayOfTheYear_149deViewedProduct',
#  'dayOfTheYear_151deViewedProduct',
#  'dayOfTheYear_56deSearchedProduct',
#  'dayOfTheYear_60deSearchedProduct',
#  'dayOfTheYear_63deSearchedProduct',
#  'dayOfTheYear_64deSearchedProduct',
#  'dayOfTheYear_66deSearchedProduct',
#  'dayOfTheYear_68deSearchedProduct',
#  'dayOfTheYear_72deSearchedProduct',
#  'dayOfTheYear_74deSearchedProduct',
#  'dayOfTheYear_83deSearchedProduct',
#  'dayOfTheYear_84deSearchedProduct',
#  'dayOfTheYear_86deSearchedProduct',
#  'dayOfTheYear_89deSearchedProduct',
#  'dayOfTheYear_92deSearchedProduct',
#  'dayOfTheYear_93deSearchedProduct',
#  'dayOfTheYear_94deSearchedProduct',
#  'dayOfTheYear_95deSearchedProduct',
#  'dayOfTheYear_96deSearchedProduct',
#  'dayOfTheYear_97deSearchedProduct',
#  'dayOfTheYear_102deSearchedProduct',
#  'dayOfTheYear_110deSearchedProduct',
#  'dayOfTheYear_113deSearchedProduct',
#  'dayOfTheYear_122deSearchedProduct',
#  'dayOfTheYear_123deSearchedProduct',
#  'dayOfTheYear_140deSearchedProduct',
#  'dayOfTheYear_144deSearchedProduct',
#  'dayOfTheYear_145deSearchedProduct',
#  'dayOfTheYear_10deAdCampaignHit',
#  'dayOfTheYear_30deAdCampaignHit',
#  'dayOfTheYear_34deAdCampaignHit',
#  'dayOfTheYear_45deAdCampaignHit',
#  'dayOfTheYear_64deAdCampaignHit',
#  'dayOfTheYear_66deAdCampaignHit',
#  'dayOfTheYear_78deAdCampaignHit',
#  'dayOfTheYear_81deAdCampaignHit',
#  'dayOfTheYear_82deAdCampaignHit',
#  'dayOfTheYear_84deAdCampaignHit',
#  'dayOfTheYear_91deAdCampaignHit',
#  'dayOfTheYear_92deAdCampaignHit',
#  'dayOfTheYear_95deAdCampaignHit',
#  'dayOfTheYear_96deAdCampaignHit',
#  'dayOfTheYear_100deAdCampaignHit',
#  'dayOfTheYear_101deAdCampaignHit',
#  'dayOfTheYear_104deAdCampaignHit',
#  'dayOfTheYear_110deAdCampaignHit',
#  'dayOfTheYear_113deAdCampaignHit',
#  'dayOfTheYear_114deAdCampaignHit',
#  'dayOfTheYear_117deAdCampaignHit',
#  'dayOfTheYear_121deAdCampaignHit',
#  'dayOfTheYear_126deAdCampaignHit',
#  'dayOfTheYear_149deAdCampaignHit',
#  'dayOfTheYear_150deAdCampaignHit',
#  'dayOfTheYear_151deAdCampaignHit',
#  'dayOfTheYear_1brandListing',
#  'dayOfTheYear_27brandListing',
#  'dayOfTheYear_31brandListing',
#  'dayOfTheYear_34brandListing',
#  'dayOfTheYear_65brandListing',
#  'dayOfTheYear_84brandListing',
#  'dayOfTheYear_85brandListing',
#  'dayOfTheYear_86brandListing',
#  'dayOfTheYear_88brandListing',
#  'dayOfTheYear_89brandListing',
#  'dayOfTheYear_90brandListing',
#  'dayOfTheYear_91brandListing',
#  'dayOfTheYear_92brandListing',
#  'dayOfTheYear_94brandListing',
#  'dayOfTheYear_97brandListing',
#  'dayOfTheYear_106brandListing',
#  'dayOfTheYear_109brandListing',
#  'dayOfTheYear_112brandListing',
#  'dayOfTheYear_127brandListing',
#  'dayOfTheYear_128brandListing',
#  'dayOfTheYear_140brandListing',
#  'dayOfTheYear_142brandListing',
#  'dayOfTheYear_145brandListing',
#  'dayOfTheYear_151brandListing',
#  'city_Altinopolis',
#  'city_Anama',
#  'city_Atlanta',
#  'city_Cacoal',
#  'city_Fort Worth',
#  'city_Fortaleza',
#  'city_Goiânia',
#  'city_Itapevi',
#  'city_Joao Neiva',
#  'city_Luziania',
#  'city_Natal',
#  'city_Navegantes',
#  'city_Olinda',
#  'city_Oliveira',
#  'city_Osasco',
#  'city_Paranapanema',
#  'city_Picos',
#  'city_Piripiri',
#  'city_Recife',
#  'city_Salvador',
#  'city_Santo André',
#  'city_Serra Azul',
#  'city_São José dos Campos',
#  'city_Tapejara',
#  'city_Unknown',
#  'city_Vitoria de Santo Antao',
#  'city_Vitória']

# %%
def xgboost(X_p, y_p, X_train_p, X_test_p, y_train_p, y_test_p):
    xg_reg = xgb.XGBClassifier(learning_rate =0.05,n_estimators=1000,max_depth=5,min_child_weight=1,gamma=0,
                           subsample=0.8,colsample_bytree=0.8,objective= 'binary:logistic',nthread=4,
                            seed=27)
    xg_reg.fit(X_train_p,y_train_p, early_stopping_rounds = 5, eval_set=[(X_test, y_test)])
    preds = xg_reg.predict(X_test_p)
    preds_prob = xg_reg.predict_proba(X_test_p)[:,1]
    train_accuracy = accuracy_score(y_train_p, xg_reg.predict(X_train_p))
    test_accuracy = accuracy_score(y_test_p, preds)
    area_debajo_de_curva = roc_auc_score(y_test_p, preds_prob)
    matriz_de_confusion = confusion_matrix(y_test_p, preds)
    print('train acurracy: ')
    print(train_accuracy)
    print('test acurracy: ')
    print(test_accuracy)
    print('Matriz de confusión: ')
    print(matriz_de_confusion)
    print('Área bajo la curva: ')
    print(area_debajo_de_curva)
    return(xg_reg)

# %%
xg_reg =xgboost(X, y, X_train, X_test, y_train, y_test)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [0]	validation_0-error:0.050978
# Will train until validation_0-error hasn't improved in 5 rounds.
# [1]	validation_0-error:0.048919
# [2]	validation_0-error:0.048919
# [3]	validation_0-error:0.048404
# [4]	validation_0-error:0.048404
# [5]	validation_0-error:0.048919
# [6]	validation_0-error:0.048404
# [7]	validation_0-error:0.048404
# [8]	validation_0-error:0.048404
# Stopping. Best iteration:
# [3]	validation_0-error:0.048404
#
# train acurracy:
# 0.9507211538461539
# test acurracy:
# 0.9515962924819773
# Matriz de confusión:
# [[1847    1]
#  [  93    1]]
# Área bajo la curva:
# 0.7897410656719167

# %%
scaler = preprocessing.StandardScaler().fit(X)
X_transformed = scaler.transform(X)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.

# %%
X_train, X_test, y_train, y_test = train_test_split(X_transformed, y, test_size= 0.1, random_state= 123)

xg_reg =xgboost(X_transformed, y, X_train, X_test, y_train, y_test)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [0]	validation_0-error:0.050978
# Will train until validation_0-error hasn't improved in 5 rounds.
# [1]	validation_0-error:0.048919
# [2]	validation_0-error:0.048919
# [3]	validation_0-error:0.048404
# [4]	validation_0-error:0.048404
# [5]	validation_0-error:0.048919
# [6]	validation_0-error:0.048404
# [7]	validation_0-error:0.048404
# [8]	validation_0-error:0.048404
# Stopping. Best iteration:
# [3]	validation_0-error:0.048404
#
# train acurracy:
# 0.9507211538461539
# test acurracy:
# 0.9515962924819773
# Matriz de confusión:
# [[1847    1]
#  [  93    1]]
# Área bajo la curva:
# 0.7897410656719167

# %%
rus= RandomUnderSampler(return_indices=True)

#id_rus son los índices
X_rus_train, y_rus_train, id_rus = rus.fit_sample(X_train, y_train)
print(X_rus_train)


xg_reg = xgboost(X_transformed, y ,X_rus_train, X_test, y_rus_train, y_test)
# Out:
# [[ 1.27472836 -0.41485294 -2.12272366 ... -0.06202043 -0.03261667
#   -0.02006217]
#  [ 1.27472836 -0.41485294 -2.12272366 ... -0.06202043 -0.03261667
#   -0.02006217]
#  [-0.78448086 -0.2240503   0.47109288 ... -0.06202043 -0.03261667
#   -0.02006217]
#  ...
#  [-0.78448086  0.44375894  0.47109288 ... -0.06202043 -0.03261667
#   -0.02006217]
#  [-0.78448086  0.06215366  0.47109288 ... -0.06202043 -0.03261667
#   -0.02006217]
#  [-0.78448086  0.53916026  0.47109288 ... -0.06202043 -0.03261667
#   -0.02006217]]
# [0]	validation_0-error:0.216272
# Will train until validation_0-error hasn't improved in 5 rounds.
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	validation_0-error:0.226056
# [2]	validation_0-error:0.213697
# [3]	validation_0-error:0.213697
# [4]	validation_0-error:0.214727
# [5]	validation_0-error:0.217817
# [6]	validation_0-error:0.209578
# [7]	validation_0-error:0.209063
# [8]	validation_0-error:0.212667
# [9]	validation_0-error:0.210608
# [10]	validation_0-error:0.205458
# [11]	validation_0-error:0.207518
# [12]	validation_0-error:0.207518
# [13]	validation_0-error:0.210093
# [14]	validation_0-error:0.211637
# [15]	validation_0-error:0.210608
# Stopping. Best iteration:
# [10]	validation_0-error:0.205458
#
# train acurracy:
# 0.837471783295711
# test acurracy:
# 0.7945417095777549
# Matriz de confusión:
# [[1474  374]
#  [  25   69]]
# Área bajo la curva:
# 0.840330547112462
